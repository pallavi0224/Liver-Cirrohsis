# %% [markdown]
# <a href="https://colab.research.google.com/github/pallavi0224/Liver-Cirrohsis/blob/main/Liver_Cirrhosis_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

file_name = "/content/cirrhosis1.csv"

# Load dataset as dataframe (csv file)
dataset = pd.read_csv("/content/cirrhosis1.csv")

# %%
dataset
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D              NaN  24472   F     NaN          NaN
# 414  415    1103      C              NaN  14245   F     NaN          NaN
# 415  416    1055      C              NaN  20819   F     NaN          NaN
# 416  417     691      C              NaN  21185   F     NaN          NaN
# 417  418     976      C              NaN  19358   F     NaN          NaN
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 0         Y     Y       14.5        261.0     2.60   156.0    1718.0  137.95
# 1         Y     N        1.1        302.0     4.14    54.0    7394.8  113.52
# 2         N     S        1.4        176.0     3.48   210.0     516.0   96.10
# 3         Y     S        1.8        244.0     2.54    64.0    6121.8   60.63
# 4         Y     N        3.4        279.0     3.53   143.0     671.0  113.15
# ..      ...   ...        ...          ...      ...     ...       ...     ...
# 413     NaN     N        1.2          NaN     2.96     NaN       NaN     NaN
# 414     NaN     N        0.9          NaN     3.83     NaN       NaN     NaN
# 415     NaN     N        1.6          NaN     3.42     NaN       NaN     NaN
# 416     NaN     N        0.8          NaN     3.75     NaN       NaN     NaN
# 417     NaN     N        0.7          NaN     3.29     NaN       NaN     NaN
#
#      Tryglicerides  Platelets  Prothrombin  Stage
# 0            172.0      190.0         12.2    4.0
# 1             88.0      221.0         10.6    3.0
# 2             55.0      151.0         12.0    4.0
# 3             92.0      183.0         10.3    4.0
# 4             72.0      136.0         10.9    3.0
# ..             ...        ...          ...    ...
# 413            NaN      174.0         10.9    3.0
# 414            NaN      180.0         11.2    4.0
# 415            NaN      143.0          9.9    3.0
# 416            NaN      269.0         10.4    3.0
# 417            NaN      350.0         10.6    4.0
#
# [418 rows x 20 columns]

# %%
# column of the dataset
dataset.columns
# Out:
# Index(['ID', 'N_Days', 'Status', 'Drug', 'Age', 'Sex', 'Ascites',
#        'Hepatomegaly', 'Spiders', 'Edema', 'Bilirubin', 'Cholesterol',
#        'Albumin', 'Copper', 'Alk_Phos', 'SGOT', 'Tryglicerides', 'Platelets',
#        'Prothrombin', 'Stage'],
#       dtype='object')

# %%
# Shape of the dataset
dataset.shape
# Out:
# (418, 20)

# %%
#Show first 5 rows of dataset
dataset.head()
# Out:
#    ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly Spiders  \
# 0   1     400      D  D-penicillamine  21464   F       Y            Y       Y
# 1   2    4500      C  D-penicillamine  20617   F       N            Y       Y
# 2   3    1012      D  D-penicillamine  25594   M       N            N       N
# 3   4    1925      D  D-penicillamine  19994   F       N            Y       Y
# 4   5    1504     CL          Placebo  13918   F       N            Y       Y
#
#   Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 0     Y       14.5        261.0     2.60   156.0    1718.0  137.95
# 1     N        1.1        302.0     4.14    54.0    7394.8  113.52
# 2     S        1.4        176.0     3.48   210.0     516.0   96.10
# 3     S        1.8        244.0     2.54    64.0    6121.8   60.63
# 4     N        3.4        279.0     3.53   143.0     671.0  113.15
#
#    Tryglicerides  Platelets  Prothrombin  Stage
# 0          172.0      190.0         12.2    4.0
# 1           88.0      221.0         10.6    3.0
# 2           55.0      151.0         12.0    4.0
# 3           92.0      183.0         10.3    4.0
# 4           72.0      136.0         10.9    3.0

# %%
#shows 5 random rows from dataset
dataset.sample(5)
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 30    31    3839      D          Placebo  15177   F       N            Y
# 265  266    1614      C  D-penicillamine  20567   F       N            N
# 376  377    1987      C              NaN  12053   F     NaN          NaN
# 202  203    2221      C          Placebo  13535   F       N            Y
# 92    93    3913      C  D-penicillamine  13344   F       N            N
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos   SGOT  \
# 30        N     N        4.7        296.0     3.44   114.0    9933.2  206.4
# 265       N     N        0.5        318.0     3.32    52.0     613.0   70.0
# 376     NaN     N        2.2          NaN     3.76     NaN       NaN    NaN
# 202       N     N        0.5        149.0     4.04   227.0     598.0   52.7
# 92        N     N        1.3        353.0     3.67    73.0    2039.0  232.5
#
#      Tryglicerides  Platelets  Prothrombin  Stage
# 30           101.0      195.0         10.3    2.0
# 265          260.0      279.0         10.2    3.0
# 376            NaN      253.0          9.9    3.0
# 202           57.0      166.0          9.9    2.0
# 92            68.0      380.0         11.1    2.0

# %%
#returns description of the data in the DataFrame
dataset.describe()
# Out:
#                ID       N_Days           Age   Bilirubin  Cholesterol  \
# count  418.000000   418.000000    418.000000  418.000000   284.000000
# mean   209.500000  1917.782297  18533.351675    3.220813   369.510563
# std    120.810458  1104.672992   3815.845055    4.407506   231.944545
# min      1.000000    41.000000   9598.000000    0.300000   120.000000
# 25%    105.250000  1092.750000  15644.500000    0.800000   249.500000
# 50%    209.500000  1730.000000  18628.000000    1.400000   309.500000
# 75%    313.750000  2613.500000  21272.500000    3.400000   400.000000
# max    418.000000  4795.000000  28650.000000   28.000000  1775.000000
#
#           Albumin      Copper      Alk_Phos        SGOT  Tryglicerides  \
# count  418.000000  310.000000    312.000000  312.000000     282.000000
# mean     3.497440   97.648387   1982.655769  122.556346     124.702128
# std      0.424972   85.613920   2140.388824   56.699525      65.148639
# min      1.960000    4.000000    289.000000   26.350000      33.000000
# 25%      3.242500   41.250000    871.500000   80.600000      84.250000
# 50%      3.530000   73.000000   1259.000000  114.700000     108.000000
# 75%      3.770000  123.000000   1980.000000  151.900000     151.000000
# max      4.640000  588.000000  13862.400000  457.250000     598.000000
#
#         Platelets  Prothrombin       Stage
# count  407.000000   416.000000  412.000000
# mean   257.024570    10.731731    3.024272
# std     98.325585     1.022000    0.882042
# min     62.000000     9.000000    1.000000
# 25%    188.500000    10.000000    2.000000
# 50%    251.000000    10.600000    3.000000
# 75%    318.000000    11.100000    4.000000
# max    721.000000    18.000000    4.000000

# %%
#Categorical feature
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             418 non-null    int64
#  1   N_Days         418 non-null    int64
#  2   Status         418 non-null    object
#  3   Drug           312 non-null    object
#  4   Age            418 non-null    int64
#  5   Sex            418 non-null    object
#  6   Ascites        312 non-null    object
#  7   Hepatomegaly   312 non-null    object
#  8   Spiders        312 non-null    object
#  9   Edema          418 non-null    object
#  10  Bilirubin      418 non-null    float64
#  11  Cholesterol    284 non-null    float64
#  12  Albumin        418 non-null    float64
#  13  Copper         310 non-null    float64
#  14  Alk_Phos       312 non-null    float64
#  15  SGOT           312 non-null    float64
#  16  Tryglicerides  282 non-null    float64
#  17  Platelets      407 non-null    float64
#  18  Prothrombin    416 non-null    float64
#  19  Stage          412 non-null    float64
# dtypes: float64(10), int64(3), object(7)
# memory usage: 65.4+ KB

# %%
#checking if there is any null
dataset.isnull().sum()
# Out:
# ID                 0
# N_Days             0
# Status             0
# Drug             106
# Age                0
# Sex                0
# Ascites          106
# Hepatomegaly     106
# Spiders          106
# Edema              0
# Bilirubin          0
# Cholesterol      134
# Albumin            0
# Copper           108
# Alk_Phos         106
# SGOT             106
# Tryglicerides    136
# Platelets         11
# Prothrombin        2
# Stage              6
# dtype: int64

# %%
import seaborn as sn
import matplotlib.pyplot as plt
# #variable_to_plot = 'Sex'
# columns = dataset.columns
# for i in range(0,len(columns)-1):
#  variable_to_plot = columns[i]
#  plt.figure(figsize=(8, 6))
#  plt.hist(dataset[variable_to_plot], edgecolor='black')
#  plt.title(f'Histogram of {variable_to_plot}')
#  plt.xlabel(variable_to_plot)
#  plt.ylabel('Frequency')
#  plt.show()
plt.figure(figsize = (30,20))
loop = dataset[["Bilirubin","Copper",'Prothrombin',"Tryglicerides","SGOT"]]
i = 0
for c in loop:
    i +=1
    plt.subplot(3,2,i)
    sn.regplot(x = dataset[c],y = dataset["Stage"],scatter=False, color='orchid',)

# %%
#Scatter plot
# import seaborn as sns
# column = dataset.columns
# for i in range(1,len(column)-1):
#   feature1 = column[i]
#   feature2 = 'Stage'
#   plt.figure(figsize=(8, 6))
#   sns.scatterplot(data=dataset, x=feature1, y=feature2, marker='o', color='blue')
#   plt.title(f'Scatter Plot of {feature1} vs Stage')
#   plt.xlabel(f'{feature1}')
#   plt.ylabel('Stage')
#   plt.show()

plt.figure(figsize = (30,20))
loop = dataset[["Albumin","Platelets","Cholesterol"]]
i = 0
for c in loop:
    i +=1
    plt.subplot(2,2,i)
    sn.regplot(x = dataset[c],y = dataset["Stage"],scatter=False, color='orchid')

# %%
plt.figure(figsize=(20,10))


plt.subplot(2,2,1)
sn.barplot(x=dataset['Stage'],y = dataset["Bilirubin"],hue=dataset['Sex'], palette='ocean', alpha=0.9)
sn.despine(top=True, right=True, bottom=True, left=True)
plt.tick_params(axis='both', which='both', bottom=False, top=False, left=False)
plt.xlabel('')
plt.title('positive correlation of gender ("Female") with Bilirubin')


plt.subplot(2,2,2)
sn.barplot(x=dataset['Stage'],y = dataset["Copper"],hue=dataset['Sex'], palette='ocean_r', alpha=0.9)
sn.despine(top=True, right=True, bottom=True, left=True)
plt.tick_params(axis='both', which='both', bottom=False, top=False, left=False)
plt.xlabel('')
plt.title('positive correlation of gender ("Female") with Copper')


plt.subplot(2,2,3)
sn.barplot(x=dataset['Stage'],y = dataset["Tryglicerides"],hue=dataset['Sex'], palette='copper_r', alpha=0.9)
sn.despine(top=True, right=True, bottom=True, left=True)
plt.tick_params(axis='both', which='both', bottom=False, top=False, left=False)
plt.xlabel('')
plt.title('positive correlation of gender ("Female") with Tryglicerides')

plt.subplot(2,2,4)
sn.barplot(x=dataset['Stage'],y = dataset["SGOT"],hue=dataset['Sex'], palette='crest', alpha=0.9)
sn.despine(top=True, right=True, bottom=True, left=True)
plt.tick_params(axis='both', which='both', bottom=False, top=False, left=False)
plt.xlabel('')
plt.title('positive correlation of gender ("Female") with SGOT')
# Out:
# Text(0.5, 1.0, 'positive correlation of gender ("Female") with SGOT')

# %% [markdown]
# DATA CLEANING

# %%
#Cleaning null value
arr = dataset.select_dtypes(include = (['int64', 'float64'])).columns
#print(arr)
for c in arr:
    dataset[c].fillna(dataset[c].median(), inplace=True)
#dataset
arr.isna()
col = dataset.select_dtypes(include=('object')).columns
#print(col)
for c in col:
    dataset[c].fillna(dataset[c].mode().values[0], inplace=True)

dataset.select_dtypes(include=('object')).isna().sum()
# Out:
# <ipython-input-51-34ecc5c91dd2>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset[c].fillna(dataset[c].median(), inplace=True)
# <ipython-input-51-34ecc5c91dd2>:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset[c].fillna(dataset[c].mode().values[0], inplace=True)
# Status          0
# Drug            0
# Sex             0
# Ascites         0
# Hepatomegaly    0
# Spiders         0
# Edema           0
# dtype: int64

# %%
dataset
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D  D-penicillamine  24472   F       N            Y
# 414  415    1103      C  D-penicillamine  14245   F       N            Y
# 415  416    1055      C  D-penicillamine  20819   F       N            Y
# 416  417     691      C  D-penicillamine  21185   F       N            Y
# 417  418     976      C  D-penicillamine  19358   F       N            Y
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 0         Y     Y       14.5        261.0     2.60   156.0    1718.0  137.95
# 1         Y     N        1.1        302.0     4.14    54.0    7394.8  113.52
# 2         N     S        1.4        176.0     3.48   210.0     516.0   96.10
# 3         Y     S        1.8        244.0     2.54    64.0    6121.8   60.63
# 4         Y     N        3.4        279.0     3.53   143.0     671.0  113.15
# ..      ...   ...        ...          ...      ...     ...       ...     ...
# 413       N     N        1.2        309.5     2.96    73.0    1259.0  114.70
# 414       N     N        0.9        309.5     3.83    73.0    1259.0  114.70
# 415       N     N        1.6        309.5     3.42    73.0    1259.0  114.70
# 416       N     N        0.8        309.5     3.75    73.0    1259.0  114.70
# 417       N     N        0.7        309.5     3.29    73.0    1259.0  114.70
#
#      Tryglicerides  Platelets  Prothrombin  Stage
# 0            172.0      190.0         12.2    4.0
# 1             88.0      221.0         10.6    3.0
# 2             55.0      151.0         12.0    4.0
# 3             92.0      183.0         10.3    4.0
# 4             72.0      136.0         10.9    3.0
# ..             ...        ...          ...    ...
# 413          108.0      174.0         10.9    3.0
# 414          108.0      180.0         11.2    4.0
# 415          108.0      143.0          9.9    3.0
# 416          108.0      269.0         10.4    3.0
# 417          108.0      350.0         10.6    4.0
#
# [418 rows x 20 columns]

# %%
dataset["Sex"].replace("M",0,inplace = True)
dataset["Sex"].replace("F",1,inplace = True)
dataset["Stage"].replace(4,"x",inplace = True)
dataset["Stage"].replace(1,0,inplace = True)
dataset["Stage"].replace(2,0,inplace = True)
dataset["Stage"].replace(3,0,inplace = True)
dataset["Stage"].replace("x",1,inplace = True)
dataset["Hepatomegaly"].replace("Y",1,inplace = True)
dataset["Hepatomegaly"].replace("N",0,inplace = True)
dataset["Ascites"].replace("Y",1,inplace = True)
dataset["Ascites"].replace("N",0,inplace = True)
dataset["Edema"].replace("Y",1,inplace = True)
dataset["Edema"].replace("N",0,inplace = True)
dataset["Edema"].replace("S",0,inplace = True)
dataset["Status"].replace("CL",0,inplace=True)
dataset["Status"].replace("C",1,inplace=True)
dataset["Status"].replace("D",0,inplace=True)
dataset["Drug"].replace("D-penicillamine",1,inplace = True)
dataset["Drug"].replace("Placebo",0,inplace = True)
dataset["Spiders"].replace("Y",1,inplace = True)
dataset["Spiders"].replace("N",0,inplace = True)

dataset
# Out:
# <ipython-input-53-fb20244ba889>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Sex"].replace("M",0,inplace = True)
# <ipython-input-53-fb20244ba889>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Sex"].replace("F",1,inplace = True)
# <ipython-input-53-fb20244ba889>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset["Sex"].replace("F",1,inplace = True)
# <ipython-input-53-fb20244ba889>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Stage"].replace(4,"x",inplace = True)
# <ipython-input-53-fb20244ba889>:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset["Stage"].replace("x",1,inplace = True)
# <ipython-input-53-fb20244ba889>:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Hepatomegaly"].replace("Y",1,inplace = True)
# <ipython-input-53-fb20244ba889>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Hepatomegaly"].replace("N",0,inplace = True)
# <ipython-input-53-fb20244ba889>:9: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset["Hepatomegaly"].replace("N",0,inplace = True)
# <ipython-input-53-fb20244ba889>:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Ascites"].replace("Y",1,inplace = True)
# <ipython-input-53-fb20244ba889>:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Ascites"].replace("N",0,inplace = True)
# <ipython-input-53-fb20244ba889>:11: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset["Ascites"].replace("N",0,inplace = True)
# <ipython-input-53-fb20244ba889>:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Edema"].replace("Y",1,inplace = True)
# <ipython-input-53-fb20244ba889>:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Edema"].replace("N",0,inplace = True)
# <ipython-input-53-fb20244ba889>:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Edema"].replace("S",0,inplace = True)
# <ipython-input-53-fb20244ba889>:14: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset["Edema"].replace("S",0,inplace = True)
# <ipython-input-53-fb20244ba889>:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Status"].replace("CL",0,inplace=True)
# <ipython-input-53-fb20244ba889>:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Status"].replace("C",1,inplace=True)
# <ipython-input-53-fb20244ba889>:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Status"].replace("D",0,inplace=True)
# <ipython-input-53-fb20244ba889>:17: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset["Status"].replace("D",0,inplace=True)
# <ipython-input-53-fb20244ba889>:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Drug"].replace("D-penicillamine",1,inplace = True)
# <ipython-input-53-fb20244ba889>:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Drug"].replace("Placebo",0,inplace = True)
# <ipython-input-53-fb20244ba889>:19: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset["Drug"].replace("Placebo",0,inplace = True)
# <ipython-input-53-fb20244ba889>:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Spiders"].replace("Y",1,inplace = True)
# <ipython-input-53-fb20244ba889>:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Spiders"].replace("N",0,inplace = True)
# <ipython-input-53-fb20244ba889>:21: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset["Spiders"].replace("N",0,inplace = True)
#       ID  N_Days  Status  Drug    Age  Sex  Ascites  Hepatomegaly  Spiders  \
# 0      1     400       0     1  21464    1        1             1        1
# 1      2    4500       1     1  20617    1        0             1        1
# 2      3    1012       0     1  25594    0        0             0        0
# 3      4    1925       0     1  19994    1        0             1        1
# 4      5    1504       0     0  13918    1        0             1        1
# ..   ...     ...     ...   ...    ...  ...      ...           ...      ...
# 413  414     681       0     1  24472    1        0             1        0
# 414  415    1103       1     1  14245    1        0             1        0
# 415  416    1055       1     1  20819    1        0             1        0
# 416  417     691       1     1  21185    1        0             1        0
# 417  418     976       1     1  19358    1        0             1        0
#
#      Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 0        1       14.5        261.0     2.60   156.0    1718.0  137.95
# 1        0        1.1        302.0     4.14    54.0    7394.8  113.52
# 2        0        1.4        176.0     3.48   210.0     516.0   96.10
# 3        0        1.8        244.0     2.54    64.0    6121.8   60.63
# 4        0        3.4        279.0     3.53   143.0     671.0  113.15
# ..     ...        ...          ...      ...     ...       ...     ...
# 413      0        1.2        309.5     2.96    73.0    1259.0  114.70
# 414      0        0.9        309.5     3.83    73.0    1259.0  114.70
# 415      0        1.6        309.5     3.42    73.0    1259.0  114.70
# 416      0        0.8        309.5     3.75    73.0    1259.0  114.70
# 417      0        0.7        309.5     3.29    73.0    1259.0  114.70
#
#      Tryglicerides  Platelets  Prothrombin  Stage
# 0            172.0      190.0         12.2      1
# 1             88.0      221.0         10.6      0
# 2             55.0      151.0         12.0      1
# 3             92.0      183.0         10.3      1
# 4             72.0      136.0         10.9      0
# ..             ...        ...          ...    ...
# 413          108.0      174.0         10.9      0
# 414          108.0      180.0         11.2      1
# 415          108.0      143.0          9.9      0
# 416          108.0      269.0         10.4      0
# 417          108.0      350.0         10.6      1
#
# [418 rows x 20 columns]

# %%
from sklearn.preprocessing import MinMaxScaler


list_of_features = ["N_Days", "Age", "Bilirubin", "Cholesterol", "Albumin", "Copper","Alk_Phos","SGOT","Tryglicerides","Platelets","Prothrombin"]

scaler = MinMaxScaler()

dataset[list_of_features] = scaler.fit_transform(dataset[list_of_features])

# %%
dataset.head()
# Out:
#    ID  N_Days  Status  Drug    Age  Sex  Ascites  Hepatomegaly  Spiders  \
# 0   1     400       0     1  21464    1        1             1        1
# 1   2    4500       1     1  20617    1        0             1        1
# 2   3    1012       0     1  25594    0        0             0        0
# 3   4    1925       0     1  19994    1        0             1        1
# 4   5    1504       0     0  13918    1        0             1        1
#
#    Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 0      1       14.5        261.0     2.60   156.0    1718.0  137.95
# 1      0        1.1        302.0     4.14    54.0    7394.8  113.52
# 2      0        1.4        176.0     3.48   210.0     516.0   96.10
# 3      0        1.8        244.0     2.54    64.0    6121.8   60.63
# 4      0        3.4        279.0     3.53   143.0     671.0  113.15
#
#    Tryglicerides  Platelets  Prothrombin  Stage
# 0          172.0      190.0         12.2      1
# 1           88.0      221.0         10.6      0
# 2           55.0      151.0         12.0      1
# 3           92.0      183.0         10.3      1
# 4           72.0      136.0         10.9      0

# %%
x_data = dataset[['ID', 'N_Days', 'Status', 'Drug',
       'Age', 'Sex', 'Ascites', 'Hepatomegaly',
       'Spiders', 'Edema','Bilirubin','Cholesterol','Albumin','Copper','Alk_Phos','SGOT','Tryglicerides','Platelets','Prothrombin']]
y_data = dataset[["Stage"]]

# %%
y_data
# Out:
#      Stage
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
# ..     ...
# 413      0
# 414      1
# 415      0
# 416      0
# 417      1
#
# [418 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x_data, y_data,
                                                    test_size = 0.2,
                                                    random_state = 1,
                                                    stratify = y_data)
print("Training data",X_test)
# Out:
# Training data       ID    N_Days  Status  Drug       Age  Sex  Ascites  Hepatomegaly  \
# 203  204  0.431005       0     0  0.695937    1        0             0
# 272  273  0.319100       1     0  0.405312    1        0             0
# 179  180  0.530501       1     0  0.312303    1        0             0
# 31    32  0.942785       1     0  0.531388    1        0             1
# 65    66  0.872949       0     1  0.386784    0        0             1
# ..   ...       ...     ...   ...       ...  ...      ...           ...
# 381  382  0.037863       0     1  0.473966    1        0             1
# 140  141  0.632941       1     1  0.397963    1        0             0
# 86    87  0.033025       0     1  0.210896    1        0             0
# 215  216  0.447413       1     1  0.630485    1        0             0
# 110  111  0.485696       0     1  0.285167    1        0             0
#
#      Spiders  Edema  Bilirubin  Cholesterol   Albumin    Copper  Alk_Phos  \
# 203        0      0   0.014440     0.081571  0.664179  0.032534  0.054150
# 272        1      0   0.068592     0.125680  0.559701  0.121575  0.102259
# 179        0      0   0.158845     0.216314  0.902985  0.068493  0.098723
# 31         0      0   0.054152     0.085801  0.514925  0.166096  0.514830
# 65         0      0   0.039711     0.185498  0.649254  0.172945  0.119351
# ..       ...    ...        ...          ...       ...       ...       ...
# 381        0      0   0.494585     0.114502  0.231343  0.118151  0.071463
# 140        0      0   0.021661     0.136556  0.675373  0.094178  0.037205
# 86         0      0   0.028881     0.135952  0.910448  0.121575  0.115741
# 215        0      0   0.007220     0.114502  0.641791  0.027397  0.041773
# 110        0      0   0.187726     0.246526  0.828358  0.125000  0.155819
#
#          SGOT  Tryglicerides  Platelets  Prothrombin
# 203  0.118705       0.044248   0.332322     0.133333
# 272  0.140752       0.146903   0.212443     0.066667
# 179  0.489209       0.076106   0.171472     0.155556
# 31   0.130448       0.221239   0.339909     0.177778
# 65   0.363309       0.244248   0.092564     0.222222
# ..        ...            ...        ...          ...
# 381  0.205036       0.132743   0.194234     0.288889
# 140  0.230216       0.040708   0.415781     0.177778
# 86   0.446043       0.069027   0.584219     0.188889
# 215  0.068345       0.132743   0.127466     0.155556
# 110  0.338129       0.079646   0.614568     0.188889
#
# [84 rows x 19 columns]

# %%
X_train.shape, X_test.shape
# Out:
# ((334, 19), (84, 19))

# %%
y_train.shape, y_test.shape
# Out:
# ((334, 1), (84, 1))

# %%
dataset.shape
# Out:
# (418, 20)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
X_train.shape
# Out:
# (334, 19)

# %%
from sklearn.metrics import accuracy_score

lr=accuracy_score(y_test, y_pred)
print(lr)
# Out:
# 0.8214285714285714

# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
#confusion matrix for LOGISTIC REGRESSION

#y_pred = model.predict(x_test)
cm = confusion_matrix(y_test,y_pred)


plt.figure(figsize = (8,6))
sn.heatmap(cm,annot = True)
plt.xlabel("predicted")
plt.ylabel("Truth")
# Out:
# Text(70.72222222222221, 0.5, 'Truth')

# %%
from sklearn.neighbors import KNeighborsClassifier
model2 = KNeighborsClassifier(n_neighbors=10)
model2.fit(X_train, y_train)
y_pred = model2.predict(X_test)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
X_train.shape
# Out:
# (334, 19)

# %%
kn=accuracy_score(y_test, y_pred)
print(kn)
# Out:
# 0.6190476190476191

# %%
cm2 = confusion_matrix(y_test,y_pred)


plt.figure(figsize = (8,6))
sn.heatmap(cm2,annot = True)
plt.xlabel("predicted")
plt.ylabel("Truth")
# Out:
# Text(70.72222222222221, 0.5, 'Truth')

# %%
from sklearn.ensemble import RandomForestClassifier
model3 =  RandomForestClassifier(n_estimators = 100,max_depth = 12,random_state = 0)
model3.fit(X_train, y_train)
y_pred = model3.predict(X_test)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
X_train.shape
# Out:
# (334, 19)

# %%
rf=accuracy_score(y_test, y_pred)
print(rf)
# Out:
# 0.7738095238095238

# %%
m3 = confusion_matrix(y_test,y_pred)


plt.figure(figsize = (8,6))
sn.heatmap(cm3,annot = True)
plt.xlabel("predicted")
plt.ylabel("Truth")
# Out:
# Text(70.72222222222221, 0.5, 'Truth')

# %%
model_names = ['KNeighbors','Logistic Regression', 'Random Forest']
accuracy_scores = [kn,lr,rf]

plt.figure(figsize=(8, 6))
plt.bar(model_names, accuracy_scores, color=['blue', 'green','red'])
plt.xlabel("Models")
plt.ylabel("Accuracy")
plt.title("Model Comparison - Accuracy Scores")
plt.ylim(0, 1.0)
plt.show()
